# %%
# !python main.py
# Out:
# PackNet训练器初始化完成
# 任务序列: ['cubs', 'cars', 'flowers']
# 剪枝率: 75.0%
# 开始PackNet多任务学习实验
#
# ...
# 对ImageNet预训练模型（任务1）执行初始剪枝
# ...
#
# 开始对ImageNet预训练权重进行剪枝...
# 开始剪枝，任务索引: 1
# 剪枝比例: 75.0%
# 模块 1: 剪枝 1296/1728 (75.00%)
# 模块 3: 剪枝 27648/36864 (75.00%)
# 模块 6: 剪枝 55296/73728 (75.00%)
# 模块 8: 剪枝 110592/147456 (75.00%)
# 模块 11: 剪枝 221184/294912 (75.00%)
# 模块 13: 剪枝 442368/589824 (75.00%)
# 模块 15: 剪枝 442368/589824 (75.00%)
# 模块 18: 剪枝 884736/1179648 (75.00%)
# 模块 20: 剪枝 1769472/2359296 (75.00%)
# 模块 22: 剪枝 1769472/2359296 (75.00%)
# 模块 25: 剪枝 1769472/2359296 (75.00%)
# 模块 27: 剪枝 1769472/2359296 (75.00%)
# 模块 29: 剪枝 1769472/2359296 (75.00%)
# 模块 33: 剪枝 77070336/102760448 (75.00%)
# 模块 36: 剪枝 12582912/16777216 (75.00%)
# ImageNet预训练模型剪枝完成
# 已更新掩码，为后续任务准备空间
#
# ...
# 训练任务 1: CUBS
# ...
# 加载 cubs 数据集 (train): 5994 张图像, 200 个类别
# 加载 cubs 数据集 (test): 5794 张图像, 200 个类别
# 为新任务准备掩码，新任务索引: 2
#
# 阶段1: 微调训练 cubs
# 当前学习率: 0.001
# Epoch 1/20
#   Batch 0, Loss: 5.3195, Acc: 0.00%
#   Batch 50, Loss: 5.3023, Acc: 0.49%
# ...
